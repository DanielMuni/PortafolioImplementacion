# %%
# !pip install --upgrade tensorflow
# !pip install tf-nightly
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 588.3 MB 6.3 kB/s
# ...
#      |████████████████████████████████| 1.7 MB 40.5 MB/s
# ...
#      |████████████████████████████████| 6.0 MB 35.0 MB/s
# ...
#      |████████████████████████████████| 439 kB 69.5 MB/s
# ...
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.9.0
#     Uninstalling tensorflow-estimator-2.9.0:
#       Successfully uninstalled tensorflow-estimator-2.9.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.9.1
#     Uninstalling tensorboard-2.9.1:
#       Successfully uninstalled tensorboard-2.9.1
#   Attempting uninstall: keras
#     Found existing installation: keras 2.9.0
#     Uninstalling keras-2.9.0:
#       Successfully uninstalled keras-2.9.0
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 1.12
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd "/content/drive/MyDrive/Modulo_2"
# !pwd
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Modulo_2
# /content/drive/MyDrive/Modulo_2

# %%
from keras.preprocessing import image 
from keras import models
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.utils import load_img, img_to_array
from keras.applications.vgg16 import preprocess_input
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.models import load_model
from imutils import paths


#to test an image, you must have a the  model already trained and stored in a file

model = models.load_model("Model_Anime_Girls_best.h5")  #model to be loaded
model.load_weights('Model_Anime_Girls_pesos.h5')

model2 = models.load_model("Model_Anime_Girls.h5")  #model to be loaded

# %%
from imutils import paths
imgs_path = 'Anime_Girls/test/' 
image_files = list(paths.list_images(imgs_path))
image_files
# Out:
# ['Anime_Girls/test/Marin Kitagawa.3.jpg',
#  'Anime_Girls/test/Marin Kitagawa.10.jpg',
#  'Anime_Girls/test/Marin Kitagawa.29.jpg',
#  'Anime_Girls/test/Marin Kitagawa.30.jpg',
#  'Anime_Girls/test/Marin Kitagawa.1.jpg',
#  'Anime_Girls/test/Yor Forger.16.jpg',
#  'Anime_Girls/test/Yor Forger.21.jpg',
#  'Anime_Girls/test/Yor Forger.22.jpg',
#  'Anime_Girls/test/Yor Forger.28.jpg',
#  'Anime_Girls/test/Yor Forger.14.jpg',
#  'Anime_Girls/test/yor.jpg',
#  'Anime_Girls/test/marin.jpg',
#  'Anime_Girls/test/Micchon Shikimori2.jpg',
#  'Anime_Girls/test/Micchon Shikimori5.jpg',
#  'Anime_Girls/test/Micchon Shikimori15.jpg',
#  'Anime_Girls/test/Micchon Shikimori21.jpg',
#  'Anime_Girls/test/Micchon Shikimori22.jpg',
#  'Anime_Girls/test/Micchon Shikimori50.jpg',
#  'Anime_Girls/test/Shikimori.jpg']

# %%
for image_file in image_files:

    #Cargamos la imagen con la que vamos a trabajar y le hago plot
    img = mpimg.imread(image_file)
    plt.subplots(figsize=(2, 2))
    imgplot = plt.imshow(img)
    plt.grid(False)
    plt.axis('off')
    plt.show()

    img = load_img(image_file, target_size=(250,250))
    x = img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    preds = model.predict(x, verbose=0)
    result = preds[0]
    answer = np.argmax(result)
    if answer == 0:
      print("Name: Yor Forger")
      print("-----------------")
    elif answer == 1:
      print("Name: Marin Kitagawa")
      print("-----------------")
    elif answer == 2:
      print("Name: Micchon Shikimori")
      print("-----------------")
# Out:
# Name: Yor Forger
# -----------------
# Name: Yor Forger
# -----------------
# Name: Yor Forger
# -----------------
# Name: Yor Forger
# -----------------
# Name: Yor Forger
# -----------------
# Name: Yor Forger
# -----------------
# Name: Yor Forger
# -----------------
# Name: Yor Forger
# -----------------
# Name: Yor Forger
# -----------------
# Name: Yor Forger
# -----------------
# Name: Yor Forger
# -----------------
# Name: Yor Forger
# -----------------
# Name: Yor Forger
# -----------------
# Name: Yor Forger
# -----------------
# Name: Marin Kitagawa
# -----------------
# Name: Yor Forger
# -----------------
# Name: Marin Kitagawa
# -----------------
# Name: Yor Forger
# -----------------
# Name: Yor Forger
# -----------------

# %%
for image_file in image_files:

    img = mpimg.imread(image_file)
    plt.subplots(figsize=(2, 2))
    imgplot = plt.imshow(img)
    plt.grid(False)
    plt.axis('off')
    plt.show()

  #Cargamos la imagen con la que vamos a trabajar y le hago plot
    img = load_img(image_file, target_size=(250,250))
    x = img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    preds = model2.predict(x, verbose=0)
    result = preds[0]
    answer = np.argmax(result)
    if answer == 0:
      print("Name: Yor Forger")
      print("-----------------")
    elif answer == 1:
      print("Name: Marin Kitagawa")
      print("-----------------")
    elif answer == 2:
      print("Name: Micchon Shikimori")
      print("-----------------")
# Out:
# Name: Yor Forger
# -----------------
# Name: Yor Forger
# -----------------
# Name: Yor Forger
# -----------------
# Name: Yor Forger
# -----------------
# Name: Yor Forger
# -----------------
# Name: Yor Forger
# -----------------
# Name: Yor Forger
# -----------------
# Name: Yor Forger
# -----------------
# Name: Yor Forger
# -----------------
# Name: Micchon Shikimori
# -----------------
# Name: Yor Forger
# -----------------
# Name: Yor Forger
# -----------------
# Name: Marin Kitagawa
# -----------------
# Name: Yor Forger
# -----------------
# Name: Yor Forger
# -----------------
# Name: Marin Kitagawa
# -----------------
# Name: Marin Kitagawa
# -----------------
# Name: Marin Kitagawa
# -----------------
# Name: Yor Forger
# -----------------
